# %% [markdown]
# # E-commerce Supply Chain Analytics
#
# ## Business Objective
#
# Build a small retail e-commerce dataset to analyse:
# - sales and revenue
# - inventory and stock-out risk
# - supplier performance
# - fulfilment performance
#
# This project demonstrates an end-to-end BI analytics workflow using
# Python, Snowflake SQL, Power BI and Tableau.

# %%
import pandas as pd          # Imports pandas for working with tabular data
import numpy as np           # Imports NumPy for numerical operations

print("Environment ready")   # Confirms that Python is running correctly
print(f"pandas: {pd.__version__}")  # Shows the installed pandas version
print(f"numpy: {np.__version__}")   # Shows the installed NumPy version
# Out:
# Environment ready
# pandas: 3.0.5
# numpy: 2.5.2

# %% [markdown]
# ## Data Model
#
# We will simulate five core business entities:
#
# - Customers — who buys
# - Products — what is sold
# - Orders — what customers purchase
# - Suppliers — who supplies products
# - Inventory — how much stock is available
#
# The data will cover 12 months and support sales, inventory,
# supplier and fulfilment analysis.
